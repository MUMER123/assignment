# %% [markdown]
# ### Name :  'Muhammad umer '
# ### email =  'uumer2428@gmail.com '
# ### whatsapp = '03155979489'

# %% [markdown]
# # ASSIGNMENT DAY - 11

# %% [markdown]
# # Performing Operations on Dataset from FAOSTAT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prod=pd.read_csv("pak_prod.csv")
prod.head()
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
# 1          5419           Yield       1717  Cereals, Total       1961  1961
# 2          5510      Production       1717  Cereals, Total       1961  1961
# 3          5312  Area harvested       1717  Cereals, Total       1962  1962
# 4          5419           Yield       1717  Cereals, Total       1962  1962
#
#      Unit    Value Flag                                   Flag Description
# ...

# %% [markdown]
# - ### Dropping few coloumns

# %%
new_set= prod.drop(["Flag Description","Element"],axis=1)
new_set.head(5)
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code  Item Code            Item  Year Code  Year    Unit    Value  \
# 0          5312       1717  Cereals, Total       1961  1961      ha  7858558
# 1          5419       1717  Cereals, Total       1961  1961   hg/ha     8564
# 2          5510       1717  Cereals, Total       1961  1961  tonnes  6729680
# 3          5312       1717  Cereals, Total       1962  1962      ha  8090856
# 4          5419       1717  Cereals, Total       1962  1962   hg/ha     8580
#
#   Flag
# 0    A
# 1   Fc
# 2    A
# 3    A
# 4   Fc

# %% [markdown]
# ### Calculating mean by groupby method

# %%
prod.groupby(["Year"]).median()
# Out:
#       Area Code  Element Code  Item Code  Year Code       Value
# Year
# 1961      165.0        5419.0     1717.0     1961.0   6729680.0
# 1962      165.0        5419.0     1717.0     1962.0   6941600.0
# 1963      165.0        5419.0     1717.0     1963.0   7208300.0
# 1964      165.0        5419.0     1717.0     1964.0   7565300.0
# 1965      165.0        5419.0     1717.0     1965.0   7866500.0
# 1966      165.0        5419.0     1717.0     1966.0   7281250.0
# 1967      165.0        5419.0     1717.0     1967.0   8166500.0
# 1968      165.0        5419.0     1717.0     1968.0   9536762.0
# 1969      165.0        5419.0     1717.0     1969.0   9706300.0
# 1970      165.0        5419.0     1717.0     1970.0   9837847.0
# 1971      165.0        5419.0     1717.0     1971.0   9473889.0
# 1972      165.0        5419.0     1717.0     1972.0   9190065.0
# 1973      165.0        5419.0     1717.0     1973.0   9602198.0
# 1974      165.0        5419.0     1717.0     1974.0   9525590.0
# ...

# %% [markdown]
# ### Counting values

# %%
prod.value_counts("Item")
# Out:
# Item
# Cereals, Total    180
# dtype: int64

# %% [markdown]
# ### Collecting data by a boolean function

# %%
prod[prod["Year"]>2000]
# Out:
#     Domain Code                        Domain  Area Code      Area  \
# 120         QCL  Crops and livestock products        165  Pakistan
# 121         QCL  Crops and livestock products        165  Pakistan
# 122         QCL  Crops and livestock products        165  Pakistan
# 123         QCL  Crops and livestock products        165  Pakistan
# 124         QCL  Crops and livestock products        165  Pakistan
# 125         QCL  Crops and livestock products        165  Pakistan
# 126         QCL  Crops and livestock products        165  Pakistan
# 127         QCL  Crops and livestock products        165  Pakistan
# 128         QCL  Crops and livestock products        165  Pakistan
# 129         QCL  Crops and livestock products        165  Pakistan
# 130         QCL  Crops and livestock products        165  Pakistan
# 131         QCL  Crops and livestock products        165  Pakistan
# 132         QCL  Crops and livestock products        165  Pakistan
# ...

# %% [markdown]
# ### collecting data for a specific index number

# %%
prod.iloc[1502]
# Out:
# Domain Code                                                       QCL
# Domain                                   Crops and livestock products
# Area Code                                                         165
# Area                                                         Pakistan
# Element Code                                                     5312
# Element                                                Area harvested
# Item Code                                                        1717
# Item                                                   Cereals, Total
# Year Code                                                        2011
# Year                                                             2011
# Unit                                                               ha
# Value                                                        13308200
# Flag                                                                A
# ...

# %%
prod[2:20]
# Out:
#    Domain Code                        Domain  Area Code      Area  \
# 2          QCL  Crops and livestock products        165  Pakistan
# 3          QCL  Crops and livestock products        165  Pakistan
# 4          QCL  Crops and livestock products        165  Pakistan
# 5          QCL  Crops and livestock products        165  Pakistan
# 6          QCL  Crops and livestock products        165  Pakistan
# 7          QCL  Crops and livestock products        165  Pakistan
# 8          QCL  Crops and livestock products        165  Pakistan
# 9          QCL  Crops and livestock products        165  Pakistan
# 10         QCL  Crops and livestock products        165  Pakistan
# 11         QCL  Crops and livestock products        165  Pakistan
# 12         QCL  Crops and livestock products        165  Pakistan
# 13         QCL  Crops and livestock products        165  Pakistan
# 14         QCL  Crops and livestock products        165  Pakistan
# ...
